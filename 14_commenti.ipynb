# %% [markdown]
# # Capitolo 14 – I commenti in Python
#
# > **Come usare questo notebook.** Esegui le celle dall'alto verso il basso (pulsante ▶ oppure `Ctrl+Invio`). Le celle di codice contengono solo codice corretto e pronto da eseguire. Gli esempi di *errore voluto* sono mostrati come testo, per non bloccare l'esecuzione. Modifica i valori e riesegui: si impara provando.

# %% [markdown]
# ### 14.3 Come si scrive un commento

# %%
# Commento: Python lo ignora.
print("Ciao!")  # Commento alla fine della riga

# %% [markdown]
# ### 14.4 Commento su riga propria vs accanto al codice

# %%
# Stampa il messaggio di benvenuto
print("Benvenuto!")

print("Il tuo nome è Anna")  # Nome dell'utente

# %% [markdown]
# ### 14.6 Commenti a blocco (un # per ogni riga)

# %%
# Questo programma calcola il prezzo totale di un acquisto.
# Prende il prezzo unitario e la quantità,
# li moltiplica e mostra il risultato.
print("Calcolo del prezzo totale")

# %% [markdown]
# ### ESEMPIO PRATICO

# %%
# Questo è il mio primo programma con commenti
print("Sto imparando Python!")    # Messaggio principale
print("I commenti sono utili")     # Nota sui commenti
# print("Questa riga non viene eseguita")
print("Fine del programma")        # Ultima riga
