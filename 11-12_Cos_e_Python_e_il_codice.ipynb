# %% [markdown]
# # Capitoli 11–12 – Che cos'è Python e che cos'è il codice
#
# > **Come usare questo notebook.** Esegui le celle dall'alto verso il basso (pulsante ▶ oppure `Ctrl+Invio`). Le celle di codice contengono solo codice corretto e pronto da eseguire. Gli esempi di *errore voluto* sono mostrati come testo, per non bloccare l'esecuzione. Modifica i valori e riesegui: si impara provando.

# %% [markdown]
# ## 11. Che cos'è Python
# Questa riga di Python è già leggibile: stampa una frase.

# %%
print("Ciao, mondo!")

# %% [markdown]
# Lo stesso risultato in **C++** (NON è Python, non si esegue in Colab) sarebbe molto più complesso:
# ```cpp
# #include <iostream>
# int main() {
#     std::cout << "Ciao, mondo!" << std::endl;
#     return 0;
# }
# ```

# %% [markdown]
# ## 12. Che cos'è il codice
# Il codice sono istruzioni precise. Maiuscole, spazi e virgolette contano.

# %%
print("Roma")
print("roma")  # diverso dal precedente: la R cambia
