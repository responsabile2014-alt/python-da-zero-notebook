# %% [markdown]
# # Capitolo 27 – Importare moduli
#
# > **Come usare questo notebook.** Esegui le celle dall'alto verso il basso (pulsante ▶ oppure `Ctrl+Invio`). Le celle di codice contengono solo codice corretto e pronto da eseguire. Gli esempi di *errore voluto* sono mostrati come testo, per non bloccare l'esecuzione. Modifica i valori e riesegui: si impara provando.

# %% [markdown]
# ### 27.2 math, random, datetime

# %%
import math
print(math.sqrt(16))
print(math.pi)

# %%
import random
numero = random.randint(1, 10)
print(numero)   # cambia a ogni esecuzione

# %%
from datetime import date
print(date.today().year)

# %% [markdown]
# ### 27.3 import math vs from math import sqrt

# %%
import math
print(math.sqrt(25))

from math import sqrt
print(sqrt(25))

# %% [markdown]
# ### 27.4 ModuleNotFoundError e pip in Colab
# Se importi un modulo non installato ottieni `ModuleNotFoundError`. In Colab si installa con una cella che inizia con `!`:
# ```python
# !pip install nome_libreria
# ```
# Per il programma di questo manuale non serve installare nulla.
