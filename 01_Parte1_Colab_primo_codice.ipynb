# %% [markdown]
# # Parte 1 – Google Colab: il tuo primo codice
#
# > **Come usare questo notebook.** Esegui le celle dall'alto verso il basso (pulsante ▶ oppure `Ctrl+Invio`). Le celle di codice contengono solo codice corretto e pronto da eseguire. Gli esempi di *errore voluto* sono mostrati come testo, per non bloccare l'esecuzione. Modifica i valori e riesegui: si impara provando.

# %% [markdown]
# ## 7. Il primo codice in Colab
# La funzione `print()` mostra del testo nell'output.

# %%
print("Ciao, mondo!")

# %% [markdown]
# Puoi usare anche le virgolette singole: il risultato è identico.

# %%
print('Ciao, mondo!')

# %% [markdown]
# ### 7.7 Stampare più cose

# %%
print("Prima riga")
print("Seconda riga")
print("Terza riga")

# %%
print(42)
print(3.14)

# %%
print("Il mio numero preferito è", 7)

# %% [markdown]
# ### 7.8 I commenti (Python ignora tutto ciò che segue #)

# %%
# Questo è un commento. Python lo ignora.
print("Ciao, mondo!")  # Anche questo è un commento

# %% [markdown]
# ---
# ## 10. Mini esercizi (cap. 10)
# Prova a svolgerli; sotto trovi una soluzione.

# %% [markdown]
# **Esercizio 5 – Scrivere il primo print**

# %%
print("Ciao, mondo!")

# %% [markdown]
# **Esercizio 7 – Aggiungere un commento**

# %%
# Questo è il mio primo programma Python
print("Ciao, mondo!")

# %% [markdown]
# **Esercizio 11 – Correggere un errore**
#
# Il codice qui sotto è SBAGLIATO (manca la parentesi chiusa); in Colab darebbe:
# ```
# SyntaxError: '(' was never closed
# ```
# ```python
# print("Buongiorno Italia"
# ```
# La versione corretta:

# %%
print("Buongiorno Italia")
